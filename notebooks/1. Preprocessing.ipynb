# %%
import sys
import pandas as pd

sys.path.insert(1, '..')
import src.constants as cst
import src.preprocessing as prep

# %% [markdown]
# # Load data

# %%
train = pd.read_csv(cst.RAW_NB_TRAIN_PATH, index_col=0, low_memory=False)
test = pd.read_csv(cst.RAW_NB_TEST_PATH, index_col=0)

# %% [markdown]
# # Data exploration

# %%
train.head(2)
# Out:
#         Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# index
# 249338              NaN                 NaN             NaN             NaN
# 249339              NaN                 NaN             NaN             NaN
#
#         3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# index
# 249338             NaN             NaN             NaN               1
# 249339             NaN             NaN             NaN               1
#
#         Date mutation Nature mutation  ...  Nombre pieces principales  \
# index                                  ...
# 249338           1256           Vente  ...                        3.0
# 249339           1263           Vente  ...                        3.0
#
#        Nature culture Nature culture speciale Surface terrain       lon  \
# index
# 249338            NaN                     NaN             NaN  2.253080
# 249339            NaN                     NaN             NaN  2.252551
#
# ...

# %%
test.head(2)
# Out:
#         Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# index
# 249349              NaN                 NaN             NaN             NaN
# 249400              NaN                 NaN             NaN             NaN
#
#         3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# index
# 249349             NaN             NaN             NaN               1
# 249400             NaN             NaN             NaN               1
#
#         Date mutation Nature mutation  ...  Surface reelle bati  \
# index                                  ...
# 249349           1530           Vente  ...                 78.0
# 249400           1532           Vente  ...                 34.0
#
#        Nombre pieces principales Nature culture  Nature culture speciale  \
# index
# 249349                       4.0            NaN                      NaN
# 249400                       1.0            NaN                      NaN
#
# ...

# %% [markdown]
# # Dataset cleaning

# %%
prepared_train = prep.prepare_housing_data(train, is_train=True)
prepared_test = prep.prepare_housing_data(test, is_train=False)

print(prepared_train.shape, prepared_test.shape)
# Out:
# (18631, 15) (1391, 14)

# %%
preprocessed_train = prep.preprocess_housing_data(prepared_train, is_train=True)
preprocessed_test = prep.preprocess_housing_data(prepared_test, is_train=False)

# %%
preprocessed_train.to_csv(cst.PREPROCESSED_NB_TRAIN_PATH, index=True)
preprocessed_test.to_csv(cst.PREPROCESSED_NB_TEST_PATH, index=True)
